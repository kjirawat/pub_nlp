# %% [markdown]
# <a href="https://colab.research.google.com/github/kjirawat/pub_nlp/blob/main/test_nb_gh_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### test colab github 01

# %%
print("teset nb gh 01")
print("more test line 2")
# Out:
# teset nb gh 01
# more test line 2
